# %% [markdown]
# ### Part I (18 points):
#   - Working with HTML, XML, and JSON
# Pick three of your favorite books on one of your favorite subjects. At least one of the books should have more
# than one author.
#   - For each book, include the title, authors, and two or three other attributes that you find
# interesting.
#   - Take the information that you’ve selected about these three books, and separately create three
# files which store the book’s information in HTML (using an html table), XML, and JSON formats (e.g.
# “books.html”, “books.xml”, and “books.json”). To help you better understand the different file structures, I’d
# prefer that you create each of these files “by hand” unless you’re already very comfortable with the file
# formats.
#   - Write Python code, using your packages of choice, to load the information from each of the three
# sources into separate PANDAS data frames.
#   - Are the three data frames identical?
#   - Your deliverable is the three
# source files and the Python code. Post the three source files to GitHub and package your Python code within a
# Jupyter notebook (along with your code for Part II below) and post it to GitHub as well.

# %%
import pandas as pd
import json

# %%
# Read JSON File from Github and convert to DataFrame
url = r'https://raw.githubusercontent.com/AVIMARCUS6/DAV-5400/master/Fall/Datasets/books2.json'
df = pd.read_json(url)

# %%
df
# Out:
#                                          Title  \
# 0                     The Kimball Group Reader
# 1    Project Management The Managerial Process
# 2  Project Management for Non-Project Managers
#
#                                               Author            ISBN  \
# 0                          Ralph Kimball, Margy Ross  978-1119216315
# 1  Clifford F. Gray, Erik W. Larson, Gautam V. Desai  978-9339212032
# 2                                       Jack Ferraro  978-0814417362
#
#   Amazon Price
# 0       $50.00
# 1       $28.03
# 2       $26.09

# %% [markdown]
# ***

# %% [markdown]
# ### XML:

# %%
from bs4 import BeautifulSoup
import urllib

url = r'https://raw.githubusercontent.com/AVIMARCUS6/DAV-5400/master/Fall/Datasets/books.xml'
response = urllib.request.urlopen(url)
data = response.read()      # a `bytes` object
text = data.decode('utf-8') # a `str`;
soup = BeautifulSoup(text,'xml')

#regex = "\>(.*?)\<"
books = soup.find_all('Books')

# %%
book_list = []
for book in books:
    book_list.append(book.get_text())

# %%
book_list
# Out:
# ['\nThe Kimball Group Reader\n\nRalph Kimball\nMargy Ross\n\n978-1119216315\nWiley\n$50.00\n',
#  '\nProject Management The Managerial Process\n\nClifford F. Gray\nErik W. Larson\nGautam V. Desai\n\n978-9339212032\nMgh\n$28.03\n',
#  '\nProject Management for Non-Project Managers\nJack Ferraro\n978-0814417362\nAMACOM\n$26.09\n']

# %%
df = pd.DataFrame({'Title': book_list})

# %%
df['Title'].str.split( pat='\n',expand=True)
# Out:
#   0                                            1             2  \
# 0                       The Kimball Group Reader
# 1      Project Management The Managerial Process
# 2    Project Management for Non-Project Managers  Jack Ferraro
#
#                   3               4                5               6  \
# 0     Ralph Kimball      Margy Ross                   978-1119216315
# 1  Clifford F. Gray  Erik W. Larson  Gautam V. Desai
# 2    978-0814417362          AMACOM           $26.09
#
#                 7       8       9    10
# 0           Wiley  $50.00          None
# 1  978-9339212032     Mgh  $28.03
# 2            None    None    None  None

# %% [markdown]
# ***

# %% [markdown]
# ### HTML:

# %%
# Read HTML File from Github
tables = pd.read_html('https://raw.githubusercontent.com/AVIMARCUS6/DAV-5400/master/Fall/Datasets/Books.html')

# %%
# The first item in list is the dataframe
books = tables[0]

# %%
books
# Out:
#                                          Title  \
# 0                     The Kimball Group Reader
# 1    Project Management The Managerial Process
# 2  Project Management for Non-Project Managers
#
#                                             Authors            ISBN Publisher  \
# 0                         Ralph Kimball, Margy Ross  978-1119216315     Wiley
# 1  Clifford F. Gray, Erik W. Larson, Gautam V. Desa  978-9339212032       Mgh
# 2                                      Jack Ferraro  978-0814417362    AMACOM
#
#   Amazon Price
# 0       $50.00
# 1       $28.03
# 2       $26.09

# %% [markdown]
# ***

# %% [markdown]
# ### Part II (12 points):
#   - Working with Web API’s
# The New York Times web site provides a rich set of APIs, as described here: https://developer.nytimes.com
#   - You’ll need to start by signing up for an API key.
#   - Your task is to then choose one of the New York Times APIs and construct an interface in Python to read JSON
# data accessible via the API and transform that data into a Pandas data frame that is suitable for use in data
# analysis work.

# %%
import json
import urllib.request
import bs4 as bs
from bs4 import  BeautifulSoup
import requests
import pandas as pd

# %%
apiKey = 'xp6gR9lEpsg4eIYMkGMvzN7DYraPre76'

# %%
url = 'https://api.nytimes.com/svc/books/v3/lists.json?list=hardcover-fiction&api-key=' + apiKey
# Check API response to check approval (200 = approved, 400 = Unauthorized request, 429: Too many requests.)
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
# convert the 'resp' object's JSON content into a list of native Python objects
data = resp.json()
type(data)
# Out:
# dict

# %%
# len of dictionary
len(data)
# Out:
# 5

# %%
# check content of list
data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company.  All Rights Reserved.',
#  'num_results': 15,
#  'last_modified': '2019-11-27T23:38:01-05:00',
#  'results': [{'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'bestsellers_date': '2019-11-23',
#    'published_date': '2019-12-08',
#    'rank': 1,
#    'rank_last_week': 0,
#    'weeks_on_list': 1,
#    'asterisk': 0,
#    'dagger': 0,
#    'amazon_product_url': 'https://www.amazon.com/Minute-Midnight-Atlee-Pine-Thriller/dp/1538761602?tag=NYTBS-20',
#    'isbns': [{'isbn10': '1538761602', 'isbn13': '9781538761601'},
#     {'isbn10': '1538734036', 'isbn13': '9781538734032'}],
#    'book_details': [{'title': 'A MINUTE TO MIDNIGHT',
#      'description': 'When Atlee Pine returns to her hometown to investigate her sister’s kidnapping from 30 years ago, she winds up tracking a potential serial killer.',
#      'contributor': 'by David Baldacci',
#      'author': 'David Baldacci',
#      'contributor_note': '',
#      'price': 0,
#      'age_group': '',
#      'publisher': 'Grand Central',
#      'primary_isbn13': '9781538761601',
#      'primary_isbn10': '1538761602'}],
#    'reviews': [{'book_review_link': '',
#      'first_chapter_link': '',
#      'sunday_review_link': '',
#      'article_chapter_link': ''}]},
#   {'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'bestsellers_date': '2019-11-23',
#    'published_date': '2019-12-08',
#    'rank': 2,
#    'rank_last_week': 4,
#    'weeks_on_list': 64,
#    'asterisk': 0,
#    'dagger': 0,
#    'amazon_product_url': 'https://www.amazon.com/Where-Crawdads-Sing-Delia-Owens/dp/0735219095?tag=NYTBS-20',
#    'isbns': [{'isbn10': '0735219095', 'isbn13': '9780735219090'},
#     {'isbn10': '0735219117', 'isbn13': '9780735219113'},
#     {'isbn10': '0525640371', 'isbn13': '9780525640370'},
#     {'isbn10': '0593105419', 'isbn13': '9780593105412'},
#     {'isbn10': '0593187989', 'isbn13': '9780593187982'}],
#    'book_details': [{'title': 'WHERE THE CRAWDADS SING',
#      'description': 'In a quiet town on the North Carolina coast in 1969, a young woman who survived alone in the marsh becomes a murder suspect.',
#      'contributor': 'by Delia Owens',
#      'author': 'Delia Owens',
#      'contributor_note': '',
#      'price': 0,
#      'age_group': '',
#      'publisher': 'Putnam',
#      'primary_isbn13': '9780735219090',
#      'primary_isbn10': '0735219095'}],
#    'reviews': [{'book_review_link': '',
#      'first_chapter_link': '',
#      'sunday_review_link': '',
#      'article_chapter_link': ''}]},
#   {'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'bestsellers_date': '2019-11-23',
#    'published_date': '2019-12-08',
#    'rank': 3,
#    'rank_last_week': 2,
#    'weeks_on_list': 6,
#    'asterisk': 0,
#    'dagger': 0,
#    'amazon_product_url': 'https://www.amazon.com/Guardians-Novel-John-Grisham/dp/0385544189?tag=NYTBS-20',
#    'isbns': [{'isbn10': '0385544189', 'isbn13': '9780385544184'},
#     {'isbn10': '0525639365', 'isbn13': '9780525639367'},
#     {'isbn10': '0385544200', 'isbn13': '9780385544207'}],
#    'book_details': [{'title': 'THE GUARDIANS',
#      'description': 'Cullen Post, a lawyer and Episcopal minister, antagonizes some ruthless killers when he takes on a wrongful conviction case.',
#      'contributor': 'by John Grisham',
#      'author': 'John Grisham',
#      'contributor_note': '',
#      'price': 0,
#      'age_group': '',
#      'publisher': 'Doubleday',
#      'primary_isbn13': '9780385544184',
#      'primary_isbn10': '0385544189'}],
#    'reviews': [{'book_review_link': '',
#      'first_chapter_link': '',
#      'sunday_review_link': '',
#      'article_chapter_link': ''}]},
#   {'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'bestsellers_date': '2019-11-23',
#    'published_date': '2019-12-08',
#    'rank': 4,
#    'rank_last_week': 1,
#    'weeks_on_list': 2,
#    'asterisk': 0,
#    'dagger': 0,
#    'amazon_product_url': 'https://www.amazon.com/Twisted-Twenty-Six-Stephanie-Janet-Evanovich/dp/0399180192?tag=NYTBS-20',
#    'isbns': [{'isbn10': '0399180192', 'isbn13': '9780399180194'}],
#    'book_details': [{'title': 'TWISTED TWENTY-SIX',
#      'description': 'The 26th book in the Stephanie Plum series. A New Jersey gangster’s associates go after a bounty hunter’s widowed grandmother.',
#      'contributor': 'by Janet Evanovich',
#      'author': 'Janet Evanovich',
#      'contributor_note': '',
#      'price': 0,
#      'age_group': '',
#      'publisher': 'Putnam',
#      'primary_isbn13': '9780399180194',
#      'primary_isbn10': '0399180192'}],
#    'reviews': [{'book_review_link': '',
#      'first_chapter_link': '',
#      'sunday_review_link': '',
#      'article_chapter_link': ''}]},
#   {'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'bestsellers_date': '2019-11-23',
#    'published_date': '2019-12-08',
#    'rank': 5,
#    'rank_last_week': 3,
#    'weeks_on_list': 4,
#    'asterisk': 0,
#    'dagger': 0,
#    'amazon_product_url': 'https://www.amazon.com/Blue-Moon-Jack-Reacher-Novel/dp/0399593543?tag=NYTBS-20',
#    'isbns': [{'isbn10': '0399593543', 'isbn13': '9780399593543'},
#     {'isbn10': '1524774359', 'isbn13': '9781524774356'},
#     {'isbn10': '1984882678', 'isbn13': '9781984882677'},
#     {'isbn10': '198488266X', 'isbn13': '9781984882660'}],
#    'book_details': [{'title': 'BLUE MOON',
#      'description': 'Jack Reacher gets caught up in a turf war between Ukrainian and Albanian gangs.',
#      'contributor': 'by Lee Child',
#      'author': 'Lee Child',
#      'contributor_note': '',
#      'price': 0,
#      'age_group': '',
#      'publisher': 'Delacorte',
#      'primary_isbn13': '9780399593543',
#      'primary_isbn10': '0399593543'}],
#    'reviews': [{'book_review_link': '',
#      'first_chapter_link': '',
#      'sunday_review_link': '',
#      'article_chapter_link': ''}]},
#   {'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'bestsellers_date': '2019-11-23',
#    'published_date': '2019-12-08',
#    'rank': 6,
#    'rank_last_week': 0,
#    'weeks_on_list': 1,
#    'asterisk': 0,
#    'dagger': 0,
#    'amazon_product_url': 'https://www.amazon.com/Clancy-Code-Honor-Jack-Universe-ebook/dp/B07PKJRKV7?tag=NYTBS-20',
#    'isbns': [{'isbn10': '0525541721', 'isbn13': '9780525541721'},
#     {'isbn10': '0525541748', 'isbn13': '9780525541745'}],
#    'book_details': [{'title': 'TOM CLANCY: CODE OF HONOR',
#      'description': 'President Jack Ryan learns of a plot against America when he tries to help an old friend who has been arrested in Indonesia.',
#      'contributor': 'by Marc Cameron',
#      'author': 'Marc Cameron',
#      'contributor_note': '',
#      'price': 0,
#      'age_group': '',
#      'publisher': 'Putnam',
#      'primary_isbn13': '9780525541721',
#      'primary_isbn10': '0525541721'}],
#    'reviews': [{'book_review_link': '',
#      'first_chapter_link': '',
#      'sunday_review_link': '',
#      'article_chapter_link': ''}]},
#   {'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'bestsellers_date': '2019-11-23',
#    'published_date': '2019-12-08',
#    'rank': 7,
#    'rank_last_week': 6,
#    'weeks_on_list': 9,
#    'asterisk': 0,
#    'dagger': 0,
#    'amazon_product_url': 'https://www.amazon.com/Dutch-House-Novel-Ann-Patchett/dp/0062963678?tag=NYTBS-20',
#    'isbns': [{'isbn10': '0062963678', 'isbn13': '9780062963673'},
#     {'isbn10': '0062963694', 'isbn13': '9780062963697'},
#     {'isbn10': '0062963708', 'isbn13': '9780062963703'},
#     {'isbn10': '0062963724', 'isbn13': '9780062963727'}],
#    'book_details': [{'title': 'THE DUTCH HOUSE',
#      'description': 'A sibling relationship is impacted when the family goes from poverty to wealth and back again over the course of many decades.',
#      'contributor': 'by Ann Patchett',
#      'author': 'Ann Patchett',
#      'contributor_note': '',
#      'price': 0,
#      'age_group': '',
#      'publisher': 'Harper',
#      'primary_isbn13': '9780062963673',
#      'primary_isbn10': '0062963678'}],
#    'reviews': [{'book_review_link': 'https://www.nytimes.com/2019/09/21/books/review-dutch-house-ann-patchett.html',
#      'first_chapter_link': '',
#      'sunday_review_link': '',
#      'article_chapter_link': ''}]},
#   {'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'bestsellers_date': '2019-11-23',
#    'published_date': '2019-12-08',
#    'rank': 8,
#    'rank_last_week': 5,
#    'weeks_on_list': 5,
#    'asterisk': 0,
#    'dagger': 0,
#    'amazon_product_url': 'https://www.amazon.com/Night-Renée-Ballard-Harry-Bosch/dp/0316485616?tag=NYTBS-20',
#    'isbns': [{'isbn10': '0316485616', 'isbn13': '9780316485616'},
#     {'isbn10': '0316426067', 'isbn13': '9780316426060'},
#     {'isbn10': '1549120786', 'isbn13': '9781549120787'},
#     {'isbn10': '1549120778', 'isbn13': '9781549120770'},
#     {'isbn10': '154912076X', 'isbn13': '9781549120763'},
#     {'isbn10': '1549120751', 'isbn13': '9781549120756'}],
#    'book_details': [{'title': 'THE NIGHT FIRE',
#      'description': 'Harry Bosch and Renée Ballard return to take up a case that held the attention of Bosch’s mentor.',
#      'contributor': 'by Michael Connelly',
#      'author': 'Michael Connelly',
#      'contributor_note': '',
#      'price': 0,
#      'age_group': '',
#      'publisher': 'Little, Brown',
#      'primary_isbn13': '9780316485616',
#      'primary_isbn10': '0316485616'}],
#    'reviews': [{'book_review_link': '',
#      'first_chapter_link': '',
#      'sunday_review_link': '',
#      'article_chapter_link': ''}]},
#   {'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'bestsellers_date': '2019-11-23',
#    'published_date': '2019-12-08',
#    'rank': 9,
#    'rank_last_week': 8,
#    'weeks_on_list': 11,
#    'asterisk': 0,
#    'dagger': 0,
#    'amazon_product_url': 'https://www.amazon.com/Institute-Novel-Stephen-King/dp/1982110562?tag=NYTBS-20',
#    'isbns': [{'isbn10': '1982110562', 'isbn13': '9781982110567'},
#     {'isbn10': '1982110597', 'isbn13': '9781982110598'},
#     {'isbn10': '1508279071', 'isbn13': '9781508279075'},
#     {'isbn10': '1508279063', 'isbn13': '9781508279068'},
#     {'isbn10': '1432870122', 'isbn13': '9781432870126'}],
#    'book_details': [{'title': 'THE INSTITUTE',
#      'description': 'Children with special talents are abducted and sequestered in an institution where the sinister staff seeks to extract their gifts through harsh methods.',
#      'contributor': 'by Stephen King',
#      'author': 'Stephen King',
#      'contributor_note': '',
#      'price': 0,
#      'age_group': '',
#      'publisher': 'Scribner',
#      'primary_isbn13': '9781982110567',
#      'primary_isbn10': '1982110562'}],
#    'reviews': [{'book_review_link': 'https://www.nytimes.com/2019/09/08/books/review-institute-stephen-king.html',
#      'first_chapter_link': '',
#      'sunday_review_link': '',
#      'article_chapter_link': ''}]},
#   {'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'bestsellers_date': '2019-11-23',
#    'published_date': '2019-12-08',
#    'rank': 10,
#    'rank_last_week': 7,
#    'weeks_on_list': 6,
#    'asterisk': 0,
#    'dagger': 0,
#    'amazon_product_url': 'https://www.amazon.com/Olive-Again-Novel-Elizabeth-Strout/dp/0812996542?tag=NYTBS-20',
#    'isbns': [{'isbn10': '0812996542', 'isbn13': '9780812996548'},
#     {'isbn10': '1643583816', 'isbn13': '9781643583815'}],
#    'book_details': [{'title': 'OLIVE, AGAIN',
#      'description': 'In a follow-up to the Pulitzer Prize-winning novel “Olive Kitteridge,” new relationships, including a second marriage, are encountered in a seaside town in Maine.',
#      'contributor': 'by Elizabeth Strout',
#      'author': 'Elizabeth Strout',
#      'contributor_note': '',
#      'price': 0,
#      'age_group': '',
#      'publisher': 'Random House',
#      'primary_isbn13': '9780812996548',
#      'primary_isbn10': '0812996542'}],
#    'reviews': [{'book_review_link': 'https://www.nytimes.com/2019/10/15/books/review/elizabeth-strout-olive-again.html',
#      'first_chapter_link': '',
#      'sunday_review_link': '',
#      'article_chapter_link': ''}]},
#   {'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'bestsellers_date': '2019-11-23',
#    'published_date': '2019-12-08',
#    'rank': 11,
#    'rank_last_week': 14,
#    'weeks_on_list': 9,
#    'asterisk': 0,
#    'dagger': 0,
#    'amazon_product_url': 'https://www.amazon.com/Water-Dancer-Oprahs-Book-Club/dp/0399590595?tag=NYTBS-20',
#    'isbns': [{'isbn10': '0399590595', 'isbn13': '9780399590597'},
#     {'isbn10': '0525494847', 'isbn13': '9780525494843'}],
#    'book_details': [{'title': 'THE WATER DANCER',
#      'description': 'A young man who was gifted with a mysterious power becomes part of a war between slavers and the enslaved.',
#      'contributor': 'by Ta-Nehisi Coates',
#      'author': 'Ta-Nehisi Coates',
#      'contributor_note': '',
#      'price': 0,
#      'age_group': '',
#      'publisher': 'One World',
#      'primary_isbn13': '9780399590597',
#      'primary_isbn10': '0399590595'}],
#    'reviews': [{'book_review_link': 'https://www.nytimes.com/2019/09/20/books/review-water-dancer-ta-nehisi-coates.html',
#      'first_chapter_link': '',
#      'sunday_review_link': '',
#      'article_chapter_link': ''}]},
#   {'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'bestsellers_date': '2019-11-23',
#    'published_date': '2019-12-08',
#    'rank': 12,
#    'rank_last_week': 10,
#    'weeks_on_list': 7,
#    'asterisk': 0,
#    'dagger': 0,
#    'amazon_product_url': 'https://www.amazon.com/Giver-Stars-Novel-Jojo-Moyes/dp/0399562486?tag=NYTBS-20',
#    'isbns': [{'isbn10': '0399562486', 'isbn13': '9780399562488'},
#     {'isbn10': '0399562508', 'isbn13': '9780399562501'},
#     {'isbn10': '0525530193', 'isbn13': '9780525530190'}],
#    'book_details': [{'title': 'THE GIVER OF STARS',
#      'description': 'In Depression-era Kentucky, five women refuse to be cowed by men or convention as they deliver books.',
#      'contributor': 'by Jojo Moyes',
#      'author': 'Jojo Moyes',
#      'contributor_note': '',
#      'price': 0,
#      'age_group': '',
#      'publisher': 'Pamela Dorman/Viking',
#      'primary_isbn13': '9780399562488',
#      'primary_isbn10': '0399562486'}],
#    'reviews': [{'book_review_link': '',
#      'first_chapter_link': '',
#      'sunday_review_link': '',
#      'article_chapter_link': ''}]},
#   {'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'bestsellers_date': '2019-11-23',
#    'published_date': '2019-12-08',
#    'rank': 13,
#    'rank_last_week': 9,
#    'weeks_on_list': 3,
#    'asterisk': 0,
#    'dagger': 0,
#    'amazon_product_url': 'https://www.amazon.com/Starless-Sea-Novel-Erin-Morgenstern/dp/038554121X?tag=NYTBS-20',
#    'isbns': [{'isbn10': '038554121X', 'isbn13': '9780385541213'},
#     {'isbn10': '0385541228', 'isbn13': '9780385541220'}],
#    'book_details': [{'title': 'THE STARLESS SEA',
#      'description': 'Zachary Ezra Rawlins fights to save a labyrinthine underground repository of stories.',
#      'contributor': 'by Erin Morgenstern',
#      'author': 'Erin Morgenstern',
#      'contributor_note': '',
#      'price': 0,
#      'age_group': '',
#      'publisher': 'Doubleday',
#      'primary_isbn13': '9780385541213',
#      'primary_isbn10': '038554121X'}],
#    'reviews': [{'book_review_link': 'https://www.nytimes.com/2019/10/25/books/review/starless-sea-erin-morgenstern.html',
#      'first_chapter_link': '',
#      'sunday_review_link': '',
#      'article_chapter_link': ''}]},
#   {'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'bestsellers_date': '2019-11-23',
#    'published_date': '2019-12-08',
#    'rank': 14,
#    'rank_last_week': 11,
#    'weeks_on_list': 10,
#    'asterisk': 0,
#    'dagger': 0,
#    'amazon_product_url': 'https://www.amazon.com/Testaments-Sequel-Handmaids-Tale/dp/0385543786?tag=NYTBS-20',
#    'isbns': [{'isbn10': '0385543786', 'isbn13': '9780385543781'},
#     {'isbn10': '0385543794', 'isbn13': '9780385543798'},
#     {'isbn10': '0525590455', 'isbn13': '9780525590453'}],
#    'book_details': [{'title': 'THE TESTAMENTS',
#      'description': 'In a sequel to “The Handmaid’s Tale,” old secrets bring three women together as the Republic of Gilead’s theocratic regime shows signs of decay.',
#      'contributor': 'by Margaret Atwood',
#      'author': 'Margaret Atwood',
#      'contributor_note': '',
#      'price': 0,
#      'age_group': '',
#      'publisher': 'Nan A. Talese/Doubleday',
#      'primary_isbn13': '9780385543781',
#      'primary_isbn10': '0385543786'}],
#    'reviews': [{'book_review_link': '',
#      'first_chapter_link': '',
#      'sunday_review_link': '',
#      'article_chapter_link': ''}]},
#   {'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'bestsellers_date': '2019-11-23',
#    'published_date': '2019-12-08',
#    'rank': 15,
#    'rank_last_week': 12,
#    'weeks_on_list': 7,
#    'asterisk': 0,
#    'dagger': 0,
#    'amazon_product_url': 'https://www.amazon.com/19th-Christmas-Womens-Murder-Club-ebook/dp/B07P1SSF9S?tag=NYTBS-20',
#    'isbns': [{'isbn10': '0316420271', 'isbn13': '9780316420273'},
#     {'isbn10': '031649402X', 'isbn13': '9780316494021'},
#     {'isbn10': '1549120964', 'isbn13': '9781549120961'},
#     {'isbn10': '1549120948', 'isbn13': '9781549120947'},
#     {'isbn10': '154912093X', 'isbn13': '9781549120930'},
#     {'isbn10': '1549120956', 'isbn13': '9781549120954'}],
#    'book_details': [{'title': 'THE 19TH CHRISTMAS',
#      'description': 'In the 19th installment of the Women\'s Murder Club series, detective Lindsay Boxer and company take on a fearsome criminal known only as "Loman."',
#      'contributor': 'by James Patterson and Maxine Paetro',
#      'author': 'James Patterson and Maxine Paetro',
#      'contributor_note': '',
#      'price': 0,
#      'age_group': '',
#      'publisher': 'Little, Brown',
#      'primary_isbn13': '9780316420273',
#      'primary_isbn10': '0316420271'}],
#    'reviews': [{'book_review_link': '',
#      'first_chapter_link': '',
#      'sunday_review_link': '',
#      'article_chapter_link': ''}]}]}

# %%
# the data type of the first item in the list
type(data['results'][0])
# Out:
# dict

# %%
# what's in the 'results' component of the dict?
data['results'][0]
# Out:
# {'list_name': 'Hardcover Fiction',
#  'display_name': 'Hardcover Fiction',
#  'bestsellers_date': '2019-11-23',
#  'published_date': '2019-12-08',
#  'rank': 1,
#  'rank_last_week': 0,
#  'weeks_on_list': 1,
#  'asterisk': 0,
#  'dagger': 0,
#  'amazon_product_url': 'https://www.amazon.com/Minute-Midnight-Atlee-Pine-Thriller/dp/1538761602?tag=NYTBS-20',
#  'isbns': [{'isbn10': '1538761602', 'isbn13': '9781538761601'},
#   {'isbn10': '1538734036', 'isbn13': '9781538734032'}],
#  'book_details': [{'title': 'A MINUTE TO MIDNIGHT',
#    'description': 'When Atlee Pine returns to her hometown to investigate her sister’s kidnapping from 30 years ago, she winds up tracking a potential serial killer.',
#    'contributor': 'by David Baldacci',
#    'author': 'David Baldacci',
#    'contributor_note': '',
#    'price': 0,
#    'age_group': '',
#    'publisher': 'Grand Central',
#    'primary_isbn13': '9781538761601',
#    'primary_isbn10': '1538761602'}],
#  'reviews': [{'book_review_link': '',
#    'first_chapter_link': '',
#    'sunday_review_link': '',
#    'article_chapter_link': ''}]}

# %%
# Convert extracted JSON data into a data frame
books = pd.DataFrame(data['results'])
books
# Out:
#             list_name       display_name bestsellers_date published_date  \
# 0   Hardcover Fiction  Hardcover Fiction       2019-11-23     2019-12-08
# 1   Hardcover Fiction  Hardcover Fiction       2019-11-23     2019-12-08
# 2   Hardcover Fiction  Hardcover Fiction       2019-11-23     2019-12-08
# 3   Hardcover Fiction  Hardcover Fiction       2019-11-23     2019-12-08
# 4   Hardcover Fiction  Hardcover Fiction       2019-11-23     2019-12-08
# 5   Hardcover Fiction  Hardcover Fiction       2019-11-23     2019-12-08
# 6   Hardcover Fiction  Hardcover Fiction       2019-11-23     2019-12-08
# 7   Hardcover Fiction  Hardcover Fiction       2019-11-23     2019-12-08
# 8   Hardcover Fiction  Hardcover Fiction       2019-11-23     2019-12-08
# 9   Hardcover Fiction  Hardcover Fiction       2019-11-23     2019-12-08
# 10  Hardcover Fiction  Hardcover Fiction       2019-11-23     2019-12-08
# 11  Hardcover Fiction  Hardcover Fiction       2019-11-23     2019-12-08
# 12  Hardcover Fiction  Hardcover Fiction       2019-11-23     2019-12-08
# 13  Hardcover Fiction  Hardcover Fiction       2019-11-23     2019-12-08
# 14  Hardcover Fiction  Hardcover Fiction       2019-11-23     2019-12-08
#
#     rank  rank_last_week  weeks_on_list  asterisk  dagger  \
# 0      1               0              1         0       0
# 1      2               4             64         0       0
# 2      3               2              6         0       0
# 3      4               1              2         0       0
# 4      5               3              4         0       0
# 5      6               0              1         0       0
# 6      7               6              9         0       0
# 7      8               5              5         0       0
# 8      9               8             11         0       0
# 9     10               7              6         0       0
# 10    11              14              9         0       0
# 11    12              10              7         0       0
# 12    13               9              3         0       0
# 13    14              11             10         0       0
# 14    15              12              7         0       0
#
#                                    amazon_product_url  \
# 0   https://www.amazon.com/Minute-Midnight-Atlee-P...
# 1   https://www.amazon.com/Where-Crawdads-Sing-Del...
# 2   https://www.amazon.com/Guardians-Novel-John-Gr...
# 3   https://www.amazon.com/Twisted-Twenty-Six-Step...
# 4   https://www.amazon.com/Blue-Moon-Jack-Reacher-...
# 5   https://www.amazon.com/Clancy-Code-Honor-Jack-...
# 6   https://www.amazon.com/Dutch-House-Novel-Ann-P...
# 7   https://www.amazon.com/Night-Renée-Ballard-Har...
# 8   https://www.amazon.com/Institute-Novel-Stephen...
# 9   https://www.amazon.com/Olive-Again-Novel-Eliza...
# 10  https://www.amazon.com/Water-Dancer-Oprahs-Boo...
# 11  https://www.amazon.com/Giver-Stars-Novel-Jojo-...
# 12  https://www.amazon.com/Starless-Sea-Novel-Erin...
# 13  https://www.amazon.com/Testaments-Sequel-Handm...
# 14  https://www.amazon.com/19th-Christmas-Womens-M...
#
#                                                 isbns  \
# 0   [{'isbn10': '1538761602', 'isbn13': '978153876...
# 1   [{'isbn10': '0735219095', 'isbn13': '978073521...
# 2   [{'isbn10': '0385544189', 'isbn13': '978038554...
# 3   [{'isbn10': '0399180192', 'isbn13': '978039918...
# 4   [{'isbn10': '0399593543', 'isbn13': '978039959...
# 5   [{'isbn10': '0525541721', 'isbn13': '978052554...
# 6   [{'isbn10': '0062963678', 'isbn13': '978006296...
# 7   [{'isbn10': '0316485616', 'isbn13': '978031648...
# 8   [{'isbn10': '1982110562', 'isbn13': '978198211...
# 9   [{'isbn10': '0812996542', 'isbn13': '978081299...
# 10  [{'isbn10': '0399590595', 'isbn13': '978039959...
# 11  [{'isbn10': '0399562486', 'isbn13': '978039956...
# 12  [{'isbn10': '038554121X', 'isbn13': '978038554...
# 13  [{'isbn10': '0385543786', 'isbn13': '978038554...
# 14  [{'isbn10': '0316420271', 'isbn13': '978031642...
#
#                                          book_details  \
# 0   [{'title': 'A MINUTE TO MIDNIGHT', 'descriptio...
# 1   [{'title': 'WHERE THE CRAWDADS SING', 'descrip...
# 2   [{'title': 'THE GUARDIANS', 'description': 'Cu...
# 3   [{'title': 'TWISTED TWENTY-SIX', 'description'...
# 4   [{'title': 'BLUE MOON', 'description': 'Jack R...
# 5   [{'title': 'TOM CLANCY: CODE OF HONOR', 'descr...
# 6   [{'title': 'THE DUTCH HOUSE', 'description': '...
# 7   [{'title': 'THE NIGHT FIRE', 'description': 'H...
# 8   [{'title': 'THE INSTITUTE', 'description': 'Ch...
# 9   [{'title': 'OLIVE, AGAIN', 'description': 'In ...
# 10  [{'title': 'THE WATER DANCER', 'description': ...
# 11  [{'title': 'THE GIVER OF STARS', 'description'...
# 12  [{'title': 'THE STARLESS SEA', 'description': ...
# 13  [{'title': 'THE TESTAMENTS', 'description': 'I...
# 14  [{'title': 'THE 19TH CHRISTMAS', 'description'...
#
#                                               reviews
# 0   [{'book_review_link': '', 'first_chapter_link'...
# 1   [{'book_review_link': '', 'first_chapter_link'...
# 2   [{'book_review_link': '', 'first_chapter_link'...
# 3   [{'book_review_link': '', 'first_chapter_link'...
# 4   [{'book_review_link': '', 'first_chapter_link'...
# 5   [{'book_review_link': '', 'first_chapter_link'...
# 6   [{'book_review_link': 'https://www.nytimes.com...
# 7   [{'book_review_link': '', 'first_chapter_link'...
# 8   [{'book_review_link': 'https://www.nytimes.com...
# 9   [{'book_review_link': 'https://www.nytimes.com...
# 10  [{'book_review_link': 'https://www.nytimes.com...
# 11  [{'book_review_link': '', 'first_chapter_link'...
# 12  [{'book_review_link': 'https://www.nytimes.com...
# 13  [{'book_review_link': '', 'first_chapter_link'...
# 14  [{'book_review_link': '', 'first_chapter_link'...
